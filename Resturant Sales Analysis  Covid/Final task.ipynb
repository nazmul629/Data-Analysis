# %%
import pandas as pd 
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv('./loop.csv')

# %%
# Remove First row and column null velue 
df.drop(df.columns[0], axis=1, inplace=True)
df.drop([0], axis=0,inplace=True)

# %%
df.shape
# Out:
# (50, 30)

# %%
df
# Out:
#        Unnamed: 1      Unnamed: 2                    Unnamed: 3    Unnamed: 4
# 1             NaN             NaN                           NaN           NaN  \
# 2             NaN             NaN  Avg. no of customers per day  Running time
# 3    Restaurent 1  Before covid19                           800      6AM 12AM
# 4             NaN  during covid19                             0           OFF
# 5             NaN   after covid19                           500      7AM 11PM
# 6    Restaurent 2  Before covid19                           100     6 AM-12AM
# 7             NaN  during covid19                             0           OFF
# 8             NaN   after covid19                            70     12PM-12AM
# 9    Restaurent 3  Before covid19                          100%      6AM-12AM
# 10            NaN  during covid19                             0           0FF
# 11            NaN   after covid19                           60%      7AM-11PM
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30'],
#       dtype='object')

# %%
# # Changing Column name  

#      df.rename( columns={df.columns[i]:cloumn_list[i]}, inplace=False )

# df.rename( columns={'Unnamed: 1':'Unnamed: 1'}, inplace=True )
# df.rename( columns={'Unnamed: 2':'Period'}, inplace=True )
# df.rename( columns={'Unnamed: 3':'Avg. no of customers per day'}, inplace=True )
# df.rename( columns={'Unnamed: 4':'Running time'}, inplace=True )
# df.rename( columns={'Unnamed: 5':'Grill'}, inplace=True )
# df.rename( columns={'Unnamed: 6':'Curry'}, inplace=True )
# df.rename( columns={'Unnamed: 7':'Korai'}, inplace=True )
# df.rename( columns={'Unnamed: 8':'BEEF Curry'}, inplace=True )
# df.rename( columns={'Unnamed: 9':'BEEF Kebab'}, inplace=True )
# df.rename( columns={'Unnamed: 10':'BEEF Korai'}, inplace=True )

# df.rename( columns={'Unnamed: 25':'FAST FOODS'}, inplace=True )
# df.rename( columns={'Unnamed: 26':'SALAD'}, inplace=True )
# df.rename( columns={'Unnamed: 27':'FRUIT JUICE'}, inplace=True )
# df.rename( columns={'Unnamed: 28':'TEA'}, inplace=True )
# df.rename( columns={'Unnamed: 29':'COFFEE'}, inplace=True )
# df.rename( columns={'Unnamed: 30':'SOFT DRINKS'}, inplace=True )

# %%
cloumn_list  =['Restaurent','Period','Avg. no of customers per day','Running time', 
            "chicken Grill", 'Chicken Curry',' Chicken Korai', 'Beef Curry' ,'Beef Kebab','Beef Korai', 
             'Mutton Curry', 'Mutton Kebab', 'Murron Korai',  'Fish Curry', 'Fish Fry', 'Vegetable Regular',
             'Vegetable soup,', 'Chicken soup','Thai soup' ,'PARATA','NAAN',
               'BIRIYANI Chicken', 'BIRIYANI Mutton',
               'CHINESE','FAST FOODS','SALAD','FRUIT JUICE','TEA','COFFEE','SOFT DRINKS'
            ]
for i in range(len(df.columns)):
      df.rename( columns={df.columns[i]:cloumn_list[i]}, inplace=True )

# %%
df.insert(7, 'CHICKEN','')

# %%
column_names =["chicken Grill", 'Chicken Curry',' Chicken Korai']
df[column_names].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_13682/315129484.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_names].fillna(0, inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 df['CHICKEN'] = int(df.iloc[:, 4]) + int(df.iloc[:, 5]) + int(df.iloc[:, 6])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:230, in _coerce_method.<locals>.wrapper(self)
#     222     warnings.warn(
#     223         f"Calling {converter.__name__} on a single element Series is "
#     224         "deprecated and will raise a TypeError in the future. "
#    (...)
#     227         stacklevel=find_stack_level(),
#     228     )
#     229     return converter(self.iloc[0])
# --> 230 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df
# Out:
#        Restaurent          Period Avg. no of customers per day Running time
# 3    Restaurent 1  Before covid19                          800     6AM 12AM  \
# 4             NaN  during covid19                            0          OFF
# 5             NaN   after covid19                          500     7AM 11PM
# 6    Restaurent 2  Before covid19                          100    6 AM-12AM
# 7             NaN  during covid19                            0          OFF
# 8             NaN   after covid19                           70    12PM-12AM
# 9    Restaurent 3  Before covid19                         100%     6AM-12AM
# 10            NaN  during covid19                            0          0FF
# 11            NaN   after covid19                          60%     7AM-11PM
# 12   Restaurent 4  Before covid19                         2000     5AM-12PM
# 13            NaN  during covid19                          NaN          OFF
# ...

# %%
df1
# Out:
#        Restaurent          Period Avg. no of customers per day Running time
# 0    Restaurent 1  Before covid19                          800     6AM 12AM  \
# 1             NaN  during covid19                            0          OFF
# 2             NaN   after covid19                          500     7AM 11PM
# 3    Restaurent 2  Before covid19                          100    6 AM-12AM
# 4             NaN  during covid19                            0          OFF
# 5             NaN   after covid19                           70    12PM-12AM
# 6    Restaurent 3  Before covid19                         100%     6AM-12AM
# 7             NaN  during covid19                            0          0FF
# 8             NaN   after covid19                          60%     7AM-11PM
# 9    Restaurent 4  Before covid19                         2000     5AM-12PM
# 10            NaN  during covid19                          NaN          OFF
# ...

# %%
df['Restaurent' 'Period']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RestaurentPeriod'
#
# The above exception was the direct cause of the following exception:
#
# ...

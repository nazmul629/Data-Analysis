# %%
import pandas as pd 
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv('./Res. Survey with data.xlsx - Sheet1 (1).csv')

# %%
df
# Out:
#     Unnamed: 0     Unnamed: 1      Unnamed: 2                    Unnamed: 3
# 0          NaN            NaN             NaN                           NaN  \
# 1          NaN            NaN             NaN                           NaN
# 2          NaN            NaN             NaN  Avg. no of customers per day
# 3          NaN   Restaurent 1  Before covid19                           800
# 4          NaN            NaN  during covid19                             0
# 5          NaN            NaN   after covid19                           500
# 6          NaN   Restaurent 2  Before covid19                           100
# 7          NaN            NaN  during covid19                             0
# 8          NaN            NaN   after covid19                            70
# 9          NaN   Restaurent 3  Before covid19                           100
# 10         NaN            NaN  during covid19                             0
# ...

# %%
# Remove First row and column null velue 
df.drop(df.columns[0], axis=1, inplace=True)
df.drop([0], axis=0,inplace=True)

# %%
df
# Out:
#        Unnamed: 1      Unnamed: 2                    Unnamed: 3    Unnamed: 4
# 1             NaN             NaN                           NaN           NaN  \
# 2             NaN             NaN  Avg. no of customers per day  Running time
# 3    Restaurent 1  Before covid19                           800      6AM 12AM
# 4             NaN  during covid19                             0           OFF
# 5             NaN   after covid19                           500      7AM 11PM
# 6    Restaurent 2  Before covid19                           100     6 AM-12AM
# 7             NaN  during covid19                             0           OFF
# 8             NaN   after covid19                            70     12PM-12AM
# 9    Restaurent 3  Before covid19                           100      6AM-12AM
# 10            NaN  during covid19                             0           0FF
# 11            NaN   after covid19                            60      7AM-11PM
# ...

# %%
df.shape
# Out:
# (50, 30)

# %%
df.drop([1,2], axis=0,inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30'],
#       dtype='object')

# %%
cloumn_list  =['Restaurent','Period','Avg. no of customers per day','Running time', 
            "chicken Grill", 'Chicken Curry','Chicken Korai', 'Beef Curry' ,'Beef Kebab','Beef Korai', 
             'Mutton Curry', 'Mutton Kebab', 'Mutton Korai',  'Fish Curry', 'Fish Fry', 'Vegetable Regular',
             'Vegetable soup,', 'Chicken soup','Thai soup' ,'PARATA','NAAN',
               'BIRIYANI Chicken', 'BIRIYANI Mutton',
               'CHINESE','FAST FOODS','SALAD','FRUIT JUICE','TEA','COFFEE','SOFT DRINKS'
            ]
for i in range(len(df.columns)):
      df.rename( columns={df.columns[i]:cloumn_list[i]}, inplace=True )

# %%
df
# Out:
#        Restaurent          Period Avg. no of customers per day Running time
# 3    Restaurent 1  Before covid19                          800     6AM 12AM  \
# 4             NaN  during covid19                            0          OFF
# 5             NaN   after covid19                          500     7AM 11PM
# 6    Restaurent 2  Before covid19                          100    6 AM-12AM
# 7             NaN  during covid19                            0          OFF
# 8             NaN   after covid19                           70    12PM-12AM
# 9    Restaurent 3  Before covid19                          100     6AM-12AM
# 10            NaN  during covid19                            0          0FF
# 11            NaN   after covid19                           60     7AM-11PM
# 12   Restaurent 4  Before covid19                         2000     5AM-12PM
# 13            NaN  during covid19                          NaN          OFF
# ...

# %%
# Remoive all nll value 


# all_null_value  =[ "chicken Grill", 'Chicken Curry',' Chicken Korai', 'Beef Curry' ,'Beef Kebab','Beef Korai', 
#              'Mutton Curry', 'Mutton Kebab', 'Mutton Korai',  'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#              'Vegetable soup,', 'Chicken soup','Thai soup' ,'PARATA','NAAN',
#                'BIRIYANI Chicken', 'BIRIYANI Mutton',
#                'CHINESE','FAST FOODS','SALAD','FRUIT JUICE','TEA','COFFEE','SOFT DRINKS']
# all_null_value.fillna(0)

# %%
# change the column type 
df= df[df['chicken Grill'].notnull()]
df
# Out:
#        Restaurent          Period Avg. no of customers per day Running time
# 3    Restaurent 1  Before covid19                          800     6AM 12AM  \
# 5             NaN   after covid19                          500     7AM 11PM
# 6    Restaurent 2  Before covid19                          100    6 AM-12AM
# 8             NaN   after covid19                           70    12PM-12AM
# 9    Restaurent 3  Before covid19                          100     6AM-12AM
# 11            NaN   after covid19                           60     7AM-11PM
# 12   Restaurent 4  Before covid19                         2000     5AM-12PM
# 14            NaN   after covid19                         1800     5AM-12PM
# 15   Restaurent 5  Before covid19                         1200     5AM-12PM
# 17            NaN   after covid19                          750     5AM-12PM
# 18   Restaurent 6  Before covid19                          700     5AM-12PM
# ...

# %%
df.shape
# Out:
# (32, 30)

# %%
df.isnull().sum()
# Out:
# Restaurent                      16
# Period                           0
# Avg. no of customers per day     0
# Running time                     0
# chicken Grill                    0
# Chicken Curry                    0
# Chicken Korai                    0
# Beef Curry                       0
# Beef Kebab                       0
# Beef Korai                       0
# Mutton Curry                     0
# Mutton Kebab                     0
# Mutton Korai                     0
# Fish Curry                       0
# Fish Fry                         0
# Vegetable Regular                0
# Vegetable soup,                  0
# Chicken soup                     0
# Thai soup                        0
# PARATA                           0
# NAAN                             0
# BIRIYANI Chicken                 0
# BIRIYANI Mutton                  0
# CHINESE                          0
# FAST FOODS                       0
# SALAD                            0
# FRUIT JUICE                      0
# ...

# %%
df
# Out:
#        Restaurent          Period Avg. no of customers per day Running time
# 3    Restaurent 1  Before covid19                          800     6AM 12AM  \
# 5             NaN   after covid19                          500     7AM 11PM
# 6    Restaurent 2  Before covid19                          100    6 AM-12AM
# 8             NaN   after covid19                           70    12PM-12AM
# 9    Restaurent 3  Before covid19                          100     6AM-12AM
# 11            NaN   after covid19                           60     7AM-11PM
# 12   Restaurent 4  Before covid19                         2000     5AM-12PM
# 14            NaN   after covid19                         1800     5AM-12PM
# 15   Restaurent 5  Before covid19                         1200     5AM-12PM
# 17            NaN   after covid19                          750     5AM-12PM
# 18   Restaurent 6  Before covid19                          700     5AM-12PM
# ...

# %%
df.describe()
# Out:
#           Restaurent          Period Avg. no of customers per day
# count             16              32                           32  \
# unique            16               2                           24
# top     Restaurent 1  Before covid19                         1200
# freq               1              16                            3
#
#        Running time chicken Grill Chicken Curry Chicken Korai Beef Curry
# count            32            32            32            32         32  \
# unique            7            26            27            26         28
# top        6AM 12AM           420           210             0        100
# freq              7             3             2             3          3
#
#        Beef Kebab Beef Korai  ... NAAN BIRIYANI Chicken BIRIYANI Mutton
# count          32         32  ...   32               32              32  \
# unique         14         19  ...   30               24              16
# ...

# %% [markdown]
# # Make mumber

# %%
make_int_col  =['Avg. no of customers per day','Running time', 
            "chicken Grill", 'Chicken Curry','Chicken Korai', 'Beef Curry' ,'Beef Kebab','Beef Korai', 
             'Mutton Curry', 'Mutton Kebab', 'Mutton Korai',  'Fish Curry', 'Fish Fry', 'Vegetable Regular',
             'Vegetable soup,', 'Chicken soup','Thai soup' ,'PARATA','NAAN',
               'BIRIYANI Chicken', 'BIRIYANI Mutton',
               'CHINESE','FAST FOODS','SALAD','FRUIT JUICE','TEA','COFFEE','SOFT DRINKS']

# %%
for i in range(len(make_int_col)):
  
    df[make_int_col[i]] = df[make_int_col[i]].replace('[^0-9]+', '', regex=True).astype(float).astype(int)
    df[make_int_col[i]] = pd.to_numeric(df[make_int_col[i]], errors='coerce').astype(float).astype(int)
# Out:
# /tmp/ipykernel_31153/350529229.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[make_int_col[i]] = df[make_int_col[i]].replace('[^0-9]+', '', regex=True).astype(float).astype(int)
# /tmp/ipykernel_31153/350529229.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[make_int_col[i]] = pd.to_numeric(df[make_int_col[i]], errors='coerce').astype(float).astype(int)
# /tmp/ipykernel_31153/350529229.py:3: SettingWithCopyWarning:
# ...

# %%
df['chicken Grill'].dtype
# Out:
# dtype('int64')

# %%
df['Chicken Curry'].sum()
# Out:
# 4059

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 3 to 50
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Restaurent                    16 non-null     object
#  1   Period                        32 non-null     object
#  2   Avg. no of customers per day  32 non-null     int64
#  3   Running time                  32 non-null     int64
#  4   chicken Grill                 32 non-null     int64
#  5   Chicken Curry                 32 non-null     int64
#  6   Chicken Korai                 32 non-null     int64
#  7   Beef Curry                    32 non-null     int64
#  8   Beef Kebab                    32 non-null     int64
#  9   Beef Korai                    32 non-null     int64
#  10  Mutton Curry                  32 non-null     int64
#  11  Mutton Kebab                  32 non-null     int64
#  12  Mutton Korai                  32 non-null     int64
# ...

# %%
df.shape
# Out:
# (32, 30)

# %%
df.columns
# Out:
# Index(['Restaurent', 'Period', 'Avg. no of customers per day', 'Running time',
#        'chicken Grill', 'Chicken Curry', 'Chicken Korai', 'Beef Curry',
#        'Beef Kebab', 'Beef Korai', 'Mutton Curry', 'Mutton Kebab',
#        'Mutton Korai', 'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#        'Vegetable soup,', 'Chicken soup', 'Thai soup', 'PARATA', 'NAAN',
#        'BIRIYANI Chicken', 'BIRIYANI Mutton', 'CHINESE', 'FAST FOODS', 'SALAD',
#        'FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS'],
#       dtype='object')

# %% [markdown]
# ###  People response retio

# %%
number_of_people= df.groupby('Period')['Avg. no of customers per day'].sum()
number_of_people
# Out:
# Period
# Before covid19    15045
# after covid19     11000
# Name: Avg. no of customers per day, dtype: int64

# %%
percentagesOfPeople =  number_of_people / df["Avg. no of customers per day"].sum()*100
percentagesOfPeople
# Out:
# Period
# Before covid19    57.765406
# after covid19     42.234594
# Name: Avg. no of customers per day, dtype: float64

# %%
import matplotlib.pyplot as plt
labels = ['Before covid19','After covid19']
percentages = percentagesOfPeople
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage Comparison Before and After Covid19')
plt.show()

# %% [markdown]
# ### Chicken Item  Analisis

# %%
# chicken_grill_sale = df.groupby('Period')['chicken Grill'].sum()
# chicken_grill_sale

# %%
# chicken_grillPercentages = chicken_grill_sale/number_of_people * 100
# chicken_grillPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = chicken_grillPercentages

# # Create the bar plot
# plt.bar(categories, percentages)
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %%
# chicken_currySale = df.groupby('Period')['Chicken Curry'].sum()
# chicken_currySale

# %%
# chicken_currySalePercentages = chicken_currySale/number_of_people * 100
# chicken_currySalePercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = chicken_currySalePercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %%
# chicken_koraiSale = df.groupby('Period')['Chicken Korai'].sum()
# chicken_koraiSale

# %%
# chicken_koraiPercentages = chicken_koraiSale/number_of_people * 100
# chicken_koraiPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = chicken_koraiPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %% [markdown]
# ### Beef Items  Analisis

# %%
# beef_currySale = df.groupby('Period')['Beef Curry'].sum()
# beef_currySale

# %%
# beef_curryPercentages = beef_currySale/number_of_people * 100
# beef_curryPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = beef_curryPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %%
# beefkebabSale = df.groupby('Period')['Beef Kebab'].sum()
# beefkebabSale

# %%
# beefkebabPercentages = beefkebabSale/number_of_people * 100
# beefkebabPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = beefkebabPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %%
# beefKoraiSale = df.groupby('Period')['Beef Korai'].sum()
# beefKoraiSale

# %%
# beefKoraiPercentages = beefKoraiSale/number_of_people * 100
# beefKoraiPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = beefKoraiPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %% [markdown]
# ### Mutton Item  Analisis

# %%
# muttonCurrybSale = df.groupby('Period')['Mutton Curry'].sum()
# muttonCurrybSale

# %%
# muttonCurrybPercentages = muttonCurrybSale/number_of_people * 100
# muttonCurrybPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = muttonCurrybPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %%
# muttonKababSale = df.groupby('Period')['Mutton Kebab'].sum()
# muttonKababSale

# %%
# muttonkababPercentages = muttonKababSale/number_of_people * 100
# muttonkababPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = muttonkababPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %%
# muttonKoraiSale = df.groupby('Period')['Mutton Korai'].sum()
# muttonKoraiSale

# %%
# muttonKoraiPercentages = muttonKoraiSale/number_of_people * 100
# muttonKoraiPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = muttonKoraiPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %% [markdown]
# ### Mutton Items Analisis

# %%
# fishCurryPercentages = fishCurrySale/number_of_people * 100
# fishCurryPercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = fishCurryPercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %%
# fishFrySale = df.groupby('Period')['Fish Fry'].sum()
# fishFrySale

# %% [markdown]
# ### Vegetable item Analisis

# %%
# vegetableSale = df.groupby('Period')['Vegetable Regular'].sum()
# vegetableSale

# %%
# vegetablePercentages = vegetableSale/number_of_people * 100
# vegetablePercentages

# %%
# categories = ['Before covid19', 'After covid19']
# percentages = vegetablePercentages

# # Create the bar plot
# plt.bar(categories, percentages, )
# plt.xlabel('Time')
# plt.ylabel('Percentage')
# plt.title('Percentage Comparison Before and After Covid19')
# plt.show()

# %% [markdown]
# ### Soup Items Analisis

# %%
# vegetableSoupSale = df.groupby('Period')['Vegetable soup,'].sum()
# vegetableSoupSale

# %%
# vegetableSoupPercentages = vegetableSoupSale/number_of_people * 100
# vegetableSoupPercentages

# %%
# chickenSoupSale = df.groupby('Period')['Chicken soup'].sum()
# chickenSoupSale

# %%
# chickenSoupPercentages = chickenSoupSale/number_of_people * 100
# chickenSoupPercentages

# %%
# thaiSoupSale = df.groupby('Period')['Thai soup'].sum()
# thaiSoupSale

# %%
# thaiSoupPercentages = thaiSoupSale/number_of_people * 100
# thaiSoupPercentages

# %%
df.columns
# Out:
# Index(['Restaurent', 'Period', 'Avg. no of customers per day', 'Running time',
#        'chicken Grill', 'Chicken Curry', 'Chicken Korai', 'Beef Curry',
#        'Beef Kebab', 'Beef Korai', 'Mutton Curry', 'Mutton Kebab',
#        'Mutton Korai', 'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#        'Vegetable soup,', 'Chicken soup', 'Thai soup', 'PARATA', 'NAAN',
#        'BIRIYANI Chicken', 'BIRIYANI Mutton', 'CHINESE', 'FAST FOODS', 'SALAD',
#        'FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS', 'Chicken Items',
#        'Beef Items', 'Mutton Items', 'Fish Items', 'Soup Items', 'Bread Items',
#        'Biriyani Items', 'Chinese and Fastfood Items', 'Drinks'],
#       dtype='object')

# %% [markdown]
# ## Groping  for  all categorys

# %%
df['Chicken Items']=  df['chicken Grill'] + df['Chicken Curry'] + df['Chicken Korai']

df['Beef Items']=  df['Beef Curry'] + df['Beef Kebab'] + df['Beef Korai']

df['Mutton Items']=  df['Mutton Curry'] + df['Mutton Kebab'] + df['Mutton Korai']

df['Fish Items']=  df['Fish Curry'] + df['Fish Fry']

df['Soup Items']=  df['Vegetable soup,'] + df['Chicken soup'] +df['Thai soup']

df['Bread Items'] = df['PARATA'] + df['NAAN'] 

df['Biriyani Items']=  df['BIRIYANI Mutton'] + df['BIRIYANI Chicken']

df['Chinese and Fastfood Items'] =df['CHINESE']+df['FAST FOODS']

df['Drinks'] =df['FRUIT JUICE']+df['FAST FOODS'] +df['TEA'] + df['COFFEE'] + df['SOFT DRINKS']
# Out:
# /tmp/ipykernel_31153/1894404351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chicken Items']=  df['chicken Grill'] + df['Chicken Curry'] + df['Chicken Korai']
# /tmp/ipykernel_31153/1894404351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Beef Items']=  df['Beef Curry'] + df['Beef Kebab'] + df['Beef Korai']
# /tmp/ipykernel_31153/1894404351.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ## Chicken  Sales Analysis

# %%
chicken_grill_sale = df.groupby('Period')['chicken Grill'].sum()
chicken_Curry_sale = df.groupby('Period')['Chicken Curry'].sum()
chicken_Korai_sale = df.groupby('Period')['Chicken Korai'].sum()

# %%
number_of_people = df.groupby('Period')['Chicken Items'].sum()
number_of_people
# Out:
# Period
# Before covid19    9233
# after covid19     6480
# Name: Chicken Items, dtype: int64

# %%
chicken_grillPercentages = chicken_grill_sale/number_of_people * 100
chicken_CurryPercentages = chicken_Curry_sale/number_of_people * 100
chicken_KoraiPercentages = chicken_Korai_sale/number_of_people * 100

# %%
# afore_covid19
# chicken_KoraiPercentages

# %%
labels = ['Chicken Grill','Chicken Curry','Chicken Korai']
percentages = [chicken_grillPercentages[0],chicken_CurryPercentages[0],chicken_KoraiPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Chicken Items Sales Before Covid19')
plt.show()

# %%
labels = ['Chicken Grill','Chicken Curry','Chicken Korai']
percentages = [chicken_grillPercentages[1],chicken_CurryPercentages[1],chicken_KoraiPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Chicken Items Sales After Covid19')
plt.show()

# %% [markdown]
# ##  Beef  Sales Analysis

# %%
BeefCurrySale = df.groupby('Period')['Beef Curry'].sum()
BeefKebabSale = df.groupby('Period')['Beef Kebab'].sum()
BeefKoraiSale = df.groupby('Period')['Beef Korai'].sum()
print(BeefCurrySale, BeefKebabSale,BeefKoraiSale,)
# Out:
# Period
# Before covid19    2050
# after covid19     1549
# Name: Beef Curry, dtype: int64 Period
# Before covid19    365
# after covid19     177
# Name: Beef Kebab, dtype: int64 Period
# Before covid19    506
# after covid19     280
# Name: Beef Korai, dtype: int64

# %%
numberOfpeopleforBeef = df.groupby('Period')['Beef Items'].sum()
numberOfpeopleforBeef
# Out:
# Period
# Before covid19    2921
# after covid19     2006
# Name: Beef Items, dtype: int64

# %%
BeefCurryPercentages = BeefCurrySale/numberOfpeopleforBeef * 100

BeefKababPercentages = BeefKebabSale/numberOfpeopleforBeef * 100

BeefKoraiPercentages = BeefKoraiSale/numberOfpeopleforBeef * 100

BeefKoraiPercentages
# Out:
# Period
# Before covid19    17.322835
# after covid19     13.958126
# dtype: float64

# %%
labels = ['Beef Curry','Beef Kabab','Beef Korai']
percentages = [BeefCurryPercentages[0],BeefKababPercentages[0],BeefKoraiPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Beef Items Sales Before Covid19')
plt.show()

# %%
labels = ['Beef Curry','Beef Kabab','Beef Korai']
percentages = [BeefCurryPercentages[1],BeefKababPercentages[1],BeefKoraiPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Beef Items Sales After Covid19')
plt.show()

# %% [markdown]
# ## Mutton  Sales Analysis

# %%
MuttonCurrySale = df.groupby('Period')['Mutton Curry'].sum()
MuttonKebabSale = df.groupby('Period')['Mutton Kebab'].sum()
MuttonKoraiSale = df.groupby('Period')['Mutton Korai'].sum()
print(BeefCurrySale, BeefKebabSale,BeefKoraiSale,)
# Out:
# Period
# Before covid19    2050
# after covid19     1549
# Name: Beef Curry, dtype: int64 Period
# Before covid19    365
# after covid19     177
# Name: Beef Kebab, dtype: int64 Period
# Before covid19    506
# after covid19     280
# Name: Beef Korai, dtype: int64

# %%
numberOfpeopleForMutton = df.groupby('Period')['Mutton Items'].sum()
numberOfpeopleForMutton
# Out:
# Period
# Before covid19    1121
# after covid19      669
# Name: Mutton Items, dtype: int64

# %%
MuttonCurryPercentages = MuttonCurrySale/numberOfpeopleforBeef * 100

MuttonKababPercentages = MuttonKebabSale/numberOfpeopleforBeef * 100

MuttonKoraiPercentages = MuttonKoraiSale/numberOfpeopleforBeef * 100

BeefKoraiPercentages
# Out:
# Period
# Before covid19    17.322835
# after covid19     13.958126
# dtype: float64

# %%
labels = ['Mutton Curry','Mutton Kabab','Mutton Korai']
percentages = [MuttonCurryPercentages[0],MuttonKababPercentages[0],MuttonKoraiPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Beef Items Sales Before Covid19')
plt.show()

# %%
labels = ['Mutton Curry','Mutton Kabab','Mutton Korai']
percentages = [MuttonCurryPercentages[1],MuttonKababPercentages[1],MuttonKoraiPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Beef Items Sales After Covid19')
plt.show()

# %% [markdown]
# ## Fish  Sales Analysis

# %%
fishCurrySale = df.groupby('Period')['Fish Curry'].sum()
fishFrySale = df.groupby('Period')['Fish Fry'].sum()

print(fishCurrySale, fishFrySale)
# Out:
# Period
# Before covid19    3503
# after covid19     2265
# Name: Fish Curry, dtype: int64 Period
# Before covid19    0
# after covid19     0
# Name: Fish Fry, dtype: int64

# %%
labels = ['Fish Curry','Fish Fry']
percentages = [fishCurrySale[0],fishFrySale[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All FishItems Sales After Covid19')
plt.show()

# %%
labels = ['Fish Curry','Fish Fry']
percentages = [fishCurrySale[1],fishFrySale[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All FishItems Sales Before Covid19')
plt.show()

# %%
# Out:
# Index(['Restaurent', 'Period', 'Avg. no of customers per day', 'Running time',
#        'chicken Grill', 'Chicken Curry', 'Chicken Korai', 'Beef Curry',
#        'Beef Kebab', 'Beef Korai', 'Mutton Curry', 'Mutton Kebab',
#        'Mutton Korai', 'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#        'Vegetable soup,', 'Chicken soup', 'Thai soup', 'PARATA', 'NAAN',
#        'BIRIYANI Chicken', 'BIRIYANI Mutton', 'CHINESE', 'FAST FOODS', 'SALAD',
#        'FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS', 'Chicken Items',
#        'Beef Items', 'Mutton Items', 'Fish Items', 'Soup Items', 'Bread Items',
#        'Biriyani Items', 'Chinese and Fastfood Items', 'Drinks'],
#       dtype='object')

# %% [markdown]
# ### Vegetable Sales Analisis

# %%
vegetable = df.groupby('Period')['Vegetable Regular'].sum()
vegetable
# Out:
# Period
# Before covid19    6449
# after covid19     4589
# Name: Vegetable Regular, dtype: int64

# %%
vegetableSalesPersentis  = vegetable / df['Avg. no of customers per day'].sum() *100
vegetableSalesPersentis
# Out:
# Period
# Before covid19    24.760991
# after covid19     17.619505
# Name: Vegetable Regular, dtype: float64

# %%
labels = ['Before Covid19','After Covid19']
percentages =vegetableSalesPersentis
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Vegetable Sales Before Covid19 & After Covei19')
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurent', 'Period', 'Avg. no of customers per day', 'Running time',
#        'chicken Grill', 'Chicken Curry', 'Chicken Korai', 'Beef Curry',
#        'Beef Kebab', 'Beef Korai', 'Mutton Curry', 'Mutton Kebab',
#        'Mutton Korai', 'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#        'Vegetable soup,', 'Chicken soup', 'Thai soup', 'PARATA', 'NAAN',
#        'BIRIYANI Chicken', 'BIRIYANI Mutton', 'CHINESE', 'FAST FOODS', 'SALAD',
#        'FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS', 'Chicken Items',
#        'Beef Items', 'Mutton Items', 'Fish Items', 'Soup Items', 'Bread Items',
#        'Biriyani Items', 'Chinese and Fastfood Items', 'Drinks'],
#       dtype='object')

# %% [markdown]
# ### Soup Sales Analisis

# %%
vegetableSoupSale = df.groupby('Period')['Vegetable soup,'].sum()
chickenSoupSale= df.groupby('Period')['Chicken soup'].sum()
thiSoupSale = df.groupby('Period')['Thai soup'].sum()
print(vegetableSoupSale, chickenSoupSale,thiSoupSale,)
# Out:
# Period
# Before covid19    1057
# after covid19      697
# Name: Vegetable soup,, dtype: int64 Period
# Before covid19    138
# after covid19      54
# Name: Chicken soup, dtype: int64 Period
# Before covid19    598
# after covid19     389
# Name: Thai soup, dtype: int64

# %%
numberOfpeopleForSoup= df.groupby('Period')['Soup Items'].sum()
numberOfpeopleForSoup
# Out:
# Period
# Before covid19    1793
# after covid19     1140
# Name: Soup Items, dtype: int64

# %%
vegetableSoupPercentages = vegetableSoupSale/numberOfpeopleForSoup * 100
chickenSoupPercentages = chickenSoupSale/numberOfpeopleForSoup * 100
thiSoupPercentages = thiSoupSale/numberOfpeopleForSoup * 100

# %%
labels = ['Vegetable Soup','Chicken Soup','Thai Soup']
percentages = [MuttonCurryPercentages[0],MuttonKababPercentages[0],MuttonKoraiPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Soups Items Sales Before Covid19')
plt.show()

# %%
labels = ['Vegetable Soup','Chicken Soup','Thai Soup']
percentages = [MuttonCurryPercentages[1],MuttonKababPercentages[1],MuttonKoraiPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage All Soups Items Sales After Covid19')
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurent', 'Period', 'Avg. no of customers per day', 'Running time',
#        'chicken Grill', 'Chicken Curry', 'Chicken Korai', 'Beef Curry',
#        'Beef Kebab', 'Beef Korai', 'Mutton Curry', 'Mutton Kebab',
#        'Mutton Korai', 'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#        'Vegetable soup,', 'Chicken soup', 'Thai soup', 'PARATA', 'NAAN',
#        'BIRIYANI Chicken', 'BIRIYANI Mutton', 'CHINESE', 'FAST FOODS', 'SALAD',
#        'FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS', 'Chicken Items',
#        'Beef Items', 'Mutton Items', 'Fish Items', 'Soup Items', 'Bread Items',
#        'Biriyani Items', 'Chinese and Fastfood Items', 'Drinks'],
#       dtype='object')

# %% [markdown]
# ###  Bread Items  Sales analysis

# %%
parataSale = df.groupby('Period')['PARATA'].sum()
naanSale= df.groupby('Period')['NAAN'].sum()

print(parataSale, naanSale)
# Out:
# Period
# Before covid19    4491
# after covid19     3041
# Name: PARATA, dtype: int64 Period
# Before covid19    3158
# after covid19     2347
# Name: NAAN, dtype: int64

# %%
numberOfpeopleForBread= df.groupby('Period')['Bread Items'].sum()
numberOfpeopleForBread
# Out:
# Period
# Before covid19    7649
# after covid19     5388
# Name: Bread Items, dtype: int64

# %%
parataPercentages = parataSale/numberOfpeopleForBread * 100
naanPercentages = naanSale/numberOfpeopleForBread * 100

# %%
labels = ['Parata','Naan']
percentages = [parataPercentages[0],naanPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage Bread Items Sales Before Covid19')
plt.show()

# %%
labels = ['Parata','Naan']
percentages = [parataPercentages[1],naanPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage Bread Items Sales After Covid19')
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurent', 'Period', 'Avg. no of customers per day', 'Running time',
#        'chicken Grill', 'Chicken Curry', 'Chicken Korai', 'Beef Curry',
#        'Beef Kebab', 'Beef Korai', 'Mutton Curry', 'Mutton Kebab',
#        'Mutton Korai', 'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#        'Vegetable soup,', 'Chicken soup', 'Thai soup', 'PARATA', 'NAAN',
#        'BIRIYANI Chicken', 'BIRIYANI Mutton', 'CHINESE', 'FAST FOODS', 'SALAD',
#        'FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS', 'Chicken Items',
#        'Beef Items', 'Mutton Items', 'Fish Items', 'Soup Items', 'Bread Items',
#        'Biriyani Items', 'Chinese and Fastfood Items', 'Drinks'],
#       dtype='object')

# %% [markdown]
# ###  Biriyani Items  Sales analysis

# %%
chikenBiriyaniSale = df.groupby('Period')['BIRIYANI Chicken'].sum()
muttonBiriyaniSale= df.groupby('Period')['BIRIYANI Mutton'].sum()

print(chikenBiriyaniSale, muttonBiriyaniSale)
# Out:
# Period
# Before covid19    2431
# after covid19     1303
# Name: BIRIYANI Chicken, dtype: int64 Period
# Before covid19    778
# after covid19     377
# Name: BIRIYANI Mutton, dtype: int64

# %%
numberOfpeopleForBiriyani= df.groupby('Period')['Biriyani Items'].sum()
numberOfpeopleForBiriyani
# Out:
# Period
# Before covid19    3209
# after covid19     1680
# Name: Biriyani Items, dtype: int64

# %%
chikenBiriyaniPercentages = chikenBiriyaniSale/numberOfpeopleForBiriyani * 100
muttonBiriyaniPercentages = muttonBiriyaniSale/numberOfpeopleForBiriyani * 100

# %%
labels = ['BIRIYANI Chicken','BIRIYANI Mutton']
percentages = [chikenBiriyaniPercentages[0],muttonBiriyaniPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage Biriyani Items Sales Before Covid19')
plt.show()

# %%
labels = ['BIRIYANI Chicken','BIRIYANI Mutton']
percentages = [chikenBiriyaniPercentages[1],muttonBiriyaniPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage Biriyani Items Sales After Covid19')
plt.show()

# %% [markdown]
# ## Chinese and Fastfood Items Sales analysis

# %%
chineseSale = df.groupby('Period')['CHINESE'].sum()
fastFoodsSale= df.groupby('Period')['FAST FOODS'].sum()

print(chineseSale, fastFoodsSale)
# Out:
# Period
# Before covid19    105
# after covid19      80
# Name: CHINESE, dtype: int64 Period
# Before covid19    0
# after covid19     0
# Name: FAST FOODS, dtype: int64

# %%
numberOfpeopleForChineseandFastfood= df.groupby('Period')['Chinese and Fastfood Items'].sum()
numberOfpeopleForChineseandFastfood
# Out:
# Period
# Before covid19    105
# after covid19      80
# Name: Chinese and Fastfood Items, dtype: int64

# %%
chinesePercentages = chineseSale/numberOfpeopleForChineseandFastfood * 100
fastFoodsPercentages = fastFoodsSale/numberOfpeopleForChineseandFastfood * 100

# %%
fastFoodsPercentages
# Out:
# Period
# Before covid19    0.0
# after covid19     0.0
# dtype: float64

# %%
labels = ['CHINESE','FAST FOODS']
percentages = [chinesePercentages[0],fastFoodsPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage Biriyani Items Sales Before Covid19')
plt.show()

# %%
labels = ['CHINESE','FAST FOODS']
percentages = [chinesePercentages[1],fastFoodsPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage Biriyani Items Sales After Covid19')
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurent', 'Period', 'Avg. no of customers per day', 'Running time',
#        'chicken Grill', 'Chicken Curry', 'Chicken Korai', 'Beef Curry',
#        'Beef Kebab', 'Beef Korai', 'Mutton Curry', 'Mutton Kebab',
#        'Mutton Korai', 'Fish Curry', 'Fish Fry', 'Vegetable Regular',
#        'Vegetable soup,', 'Chicken soup', 'Thai soup', 'PARATA', 'NAAN',
#        'BIRIYANI Chicken', 'BIRIYANI Mutton', 'CHINESE', 'FAST FOODS', 'SALAD',
#        'FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS', 'Chicken Items',
#        'Beef Items', 'Mutton Items', 'Fish Items', 'Soup Items', 'Bread Items',
#        'Biriyani Items', 'Chinese and Fastfood Items', 'Drinks'],
#       dtype='object')

# %% [markdown]
# ## Drinks tems Sales analysis

# %%
fruitJuiceSale = df.groupby('Period')['FRUIT JUICE'].sum()
teaSale= df.groupby('Period')['TEA'].sum()
coffeeSale = df.groupby('Period')['COFFEE'].sum()
softDrinksSale= df.groupby('Period')['SOFT DRINKS'].sum()

print(fruitJuiceSale, teaSale,coffeeSale,softDrinksSale)
# Out:
# Period
# Before covid19    2085
# after covid19     1392
# Name: FRUIT JUICE, dtype: int64 Period
# Before covid19    7409
# after covid19     6174
# Name: TEA, dtype: int64 Period
# Before covid19    776
# after covid19     469
# Name: COFFEE, dtype: int64 Period
# Before covid19    1204
# after covid19      711
# Name: SOFT DRINKS, dtype: int64

# %%
numberOfpeopleForDrinks= df.groupby('Period')['Drinks'].sum()
numberOfpeopleForDrinks
# Out:
# Period
# Before covid19    11474
# after covid19      8746
# Name: Drinks, dtype: int64

# %%
fruitJuicePercentages = fruitJuiceSale/numberOfpeopleForDrinks * 100
teaPercentages = teaSale/numberOfpeopleForDrinks * 100
coffeePercentages = coffeeSale/numberOfpeopleForDrinks * 100
softDrinksPercentages = softDrinksSale/numberOfpeopleForDrinks * 100

# %%
labels = ['FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS']
percentages = [fruitJuicePercentages[0],teaPercentages[0],coffeePercentages[0],softDrinksPercentages[0]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage of Drinks Sales Before Covid19')
plt.show()

# %%
labels = ['FRUIT JUICE', 'TEA', 'COFFEE', 'SOFT DRINKS']
percentages = [fruitJuicePercentages[1],teaPercentages[1],coffeePercentages[1],softDrinksPercentages[1]]
plt.pie(percentages, labels=labels, autopct='%1.1f%%')
plt.title('Percentage of Drinks Sales  After Covid19')
plt.show()
